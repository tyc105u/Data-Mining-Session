# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

def get_first(number):
    return int(str(number)[:1])
first_digit_US = []
first_digit_TW = []

df = pd.read_csv('usacase.csv')

# Get first digit of a number in python
num = df["New Cases"]
for i in num:
    first_digit_US.append(get_first(i))
#type(first_digit.count(i))

df = pd.read_csv('twcase.csv')
num = df["確定病例數"]
for i in num:
    first_digit_TW.append(get_first(i))

# GRAPH
plt.figure(1)
plt.title('USA Cases ' + '(Sample Size = ' + str(len(first_digit_US)) + ')')
plt.xlabel('First digit')
plt.ylabel('Occurences')
plt.bar([num for num in range(1, 10)], [first_digit_US.count(num) for num in range(1, 10)])

plt.figure(2)
plt.title('TW Cases ' + '(Sample Size = ' + str(len(first_digit_TW)) + ')')
plt.xlabel('First digit')
plt.ylabel('Occurences')
plt.bar([num for num in range(1, 10)], [first_digit_TW.count(num) for num in range(1, 10)])

plt.figure(3)
plt.title('Benfords Law')
plt.xlabel('First digit')
plt.ylabel('Distribution')
plt.bar([num for num in range(1, 10)], [math.log10((num + 1) / num) for num in range(1, 10)])
# Out:
# <BarContainer object of 9 artists>
